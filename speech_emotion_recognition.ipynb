# %% [markdown]
# # Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

import os
import sys

import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from IPython.display import Audio

import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Dataset

# %%
Crema = "/content/drive/MyDrive/Python_PNU_projects/Speech_Emotion_Recognition/Crema/"

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
# Out:
#   Emotions                                               Path
# 0     fear  /content/drive/MyDrive/Python_PNU_projects/Spe...
# 1    happy  /content/drive/MyDrive/Python_PNU_projects/Spe...
# 2  neutral  /content/drive/MyDrive/Python_PNU_projects/Spe...
# 3      sad  /content/drive/MyDrive/Python_PNU_projects/Spe...
# 4    angry  /content/drive/MyDrive/Python_PNU_projects/Spe...

# %%
plt.title('Count of Emotions', size=16)
sns.countplot(data=Crema_df, x='Emotions')
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %% [markdown]
# # Visualization

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion='angry'
path = np.array(Crema_df.Path[Crema_df.Emotions==emotion])[0]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # MFCC Extraction

# %%
labels = {'disgust':0,'happy':1,'sad':2,'neutral':3,'fear':4,'angry':5}
Crema_df.replace({'Emotions':labels},inplace=True)

# %%
num_mfcc=13
n_fft=2048
hop_length=512
SAMPLE_RATE = 22050
data = {
        "labels": [],
        "mfcc": []
    }
for i in range(7442):
    data['labels'].append(Crema_df.iloc[i,0])
    signal, sample_rate = librosa.load(Crema_df.iloc[i,1], sr=SAMPLE_RATE)
    mfcc = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T
    data["mfcc"].append(np.asarray(mfcc))
    if i%500==0:
        print(i)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000

# %% [markdown]
# # Padding MFCC to make them of equal length

# %%
X = np.asarray(data['mfcc'])
y = np.asarray(data["labels"])
# Out:
# <ipython-input-10-702a30aa7d8e>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.asarray(data['mfcc'])

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X)
X.shape
# Out:
# (7442, 216, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2)

# %%
print(X_train.shape,y_train.shape,X_validation.shape,y_validation.shape,X_test.shape,y_test.shape)
# Out:
# (5357, 216, 13) (5357,) (1340, 216, 13) (1340,) (745, 216, 13) (745,)

# %% [markdown]
# # Model

# %%
def build_model(input_shape):
    model = tf.keras.Sequential()

    model.add(LSTM(128, input_shape=input_shape, return_sequences=True))
    model.add(LSTM(64))

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(6, activation='softmax'))

    return model

# %%
# create network
input_shape = (None,13)
model = build_model(input_shape)

# compile model
optimiser = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 128)         72704
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 126,662
# Trainable params: 126,662
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 11s 25ms/step - loss: 1.5548 - accuracy: 0.3506 - val_loss: 1.4699 - val_accuracy: 0.3701
# Epoch 2/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.4712 - accuracy: 0.3872 - val_loss: 1.4606 - val_accuracy: 0.3836
# Epoch 3/100
# 168/168 [==============================] - 4s 24ms/step - loss: 1.4564 - accuracy: 0.3984 - val_loss: 1.4229 - val_accuracy: 0.4022
# Epoch 4/100
# 168/168 [==============================] - 4s 24ms/step - loss: 1.4311 - accuracy: 0.3993 - val_loss: 1.4278 - val_accuracy: 0.4037
# Epoch 5/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.4165 - accuracy: 0.4176 - val_loss: 1.4225 - val_accuracy: 0.4104
# Epoch 6/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.4028 - accuracy: 0.4254 - val_loss: 1.4589 - val_accuracy: 0.3910
# Epoch 7/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.3894 - accuracy: 0.4321 - val_loss: 1.3871 - val_accuracy: 0.4321
# Epoch 8/100
# 168/168 [==============================] - 4s 23ms/step - loss: 1.3558 - accuracy: 0.4547 - val_loss: 1.3573 - val_accuracy: 0.4500
# Epoch 9/100
# 168/168 [==============================] - 3s 18ms/step - loss: 1.3455 - accuracy: 0.4519 - val_loss: 1.3524 - val_accuracy: 0.4672
# Epoch 10/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.3243 - accuracy: 0.4646 - val_loss: 1.3259 - val_accuracy: 0.4582
# Epoch 11/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.3140 - accuracy: 0.4756 - val_loss: 1.3510 - val_accuracy: 0.4619
# Epoch 12/100
# 168/168 [==============================] - 3s 20ms/step - loss: 1.3032 - accuracy: 0.4762 - val_loss: 1.2836 - val_accuracy: 0.5037
# Epoch 13/100
# 168/168 [==============================] - 3s 21ms/step - loss: 1.2646 - accuracy: 0.5005 - val_loss: 1.2916 - val_accuracy: 0.4903
# Epoch 14/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.2446 - accuracy: 0.5107 - val_loss: 1.2457 - val_accuracy: 0.5000
# Epoch 15/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.2222 - accuracy: 0.5203 - val_loss: 1.2345 - val_accuracy: 0.5276
# Epoch 16/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.1958 - accuracy: 0.5322 - val_loss: 1.2143 - val_accuracy: 0.5343
# Epoch 17/100
# 168/168 [==============================] - 4s 24ms/step - loss: 1.1926 - accuracy: 0.5307 - val_loss: 1.2630 - val_accuracy: 0.4993
# Epoch 18/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.1647 - accuracy: 0.5415 - val_loss: 1.2234 - val_accuracy: 0.5269
# Epoch 19/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.1698 - accuracy: 0.5421 - val_loss: 1.2055 - val_accuracy: 0.5433
# Epoch 20/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.1440 - accuracy: 0.5527 - val_loss: 1.2249 - val_accuracy: 0.5269
# Epoch 21/100
# 168/168 [==============================] - 4s 22ms/step - loss: 1.1132 - accuracy: 0.5727 - val_loss: 1.2174 - val_accuracy: 0.5336
# Epoch 22/100
# 168/168 [==============================] - 3s 19ms/step - loss: 1.1090 - accuracy: 0.5731 - val_loss: 1.1982 - val_accuracy: 0.5351
# Epoch 23/100
# 168/168 [==============================] - 3s 18ms/step - loss: 1.0842 - accuracy: 0.5854 - val_loss: 1.2453 - val_accuracy: 0.5373
# Epoch 24/100
# 168/168 [==============================] - 3s 18ms/step - loss: 1.0754 - accuracy: 0.5888 - val_loss: 1.1831 - val_accuracy: 0.5590
# Epoch 25/100
# 168/168 [==============================] - 4s 21ms/step - loss: 1.0501 - accuracy: 0.6020 - val_loss: 1.2115 - val_accuracy: 0.5284
# Epoch 26/100
# 168/168 [==============================] - 4s 22ms/step - loss: 1.0255 - accuracy: 0.6108 - val_loss: 1.1686 - val_accuracy: 0.5575
# Epoch 27/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.0091 - accuracy: 0.6127 - val_loss: 1.2133 - val_accuracy: 0.5448
# Epoch 28/100
# 168/168 [==============================] - 3s 17ms/step - loss: 1.0058 - accuracy: 0.6212 - val_loss: 1.1538 - val_accuracy: 0.5694
# Epoch 29/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.9768 - accuracy: 0.6308 - val_loss: 1.2062 - val_accuracy: 0.5299
# Epoch 30/100
# 168/168 [==============================] - 4s 23ms/step - loss: 0.9674 - accuracy: 0.6360 - val_loss: 1.1805 - val_accuracy: 0.5604
# Epoch 31/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.9749 - accuracy: 0.6311 - val_loss: 1.2256 - val_accuracy: 0.5313
# Epoch 32/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.9456 - accuracy: 0.6397 - val_loss: 1.1891 - val_accuracy: 0.5642
# Epoch 33/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.9237 - accuracy: 0.6507 - val_loss: 1.2425 - val_accuracy: 0.5515
# Epoch 34/100
# 168/168 [==============================] - 4s 24ms/step - loss: 0.9176 - accuracy: 0.6565 - val_loss: 1.1983 - val_accuracy: 0.5604
# Epoch 35/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.9170 - accuracy: 0.6489 - val_loss: 1.1699 - val_accuracy: 0.5575
# Epoch 36/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.8792 - accuracy: 0.6698 - val_loss: 1.2305 - val_accuracy: 0.5530
# Epoch 37/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.8567 - accuracy: 0.6784 - val_loss: 1.2128 - val_accuracy: 0.5694
# Epoch 38/100
# 168/168 [==============================] - 4s 21ms/step - loss: 0.8580 - accuracy: 0.6789 - val_loss: 1.2484 - val_accuracy: 0.5493
# Epoch 39/100
# 168/168 [==============================] - 3s 20ms/step - loss: 0.8493 - accuracy: 0.6793 - val_loss: 1.1887 - val_accuracy: 0.5776
# Epoch 40/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.8384 - accuracy: 0.6795 - val_loss: 1.1983 - val_accuracy: 0.5619
# Epoch 41/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.8130 - accuracy: 0.6983 - val_loss: 1.2273 - val_accuracy: 0.5545
# Epoch 42/100
# 168/168 [==============================] - 3s 19ms/step - loss: 0.7959 - accuracy: 0.7038 - val_loss: 1.2483 - val_accuracy: 0.5679
# Epoch 43/100
# 168/168 [==============================] - 4s 22ms/step - loss: 0.7753 - accuracy: 0.7095 - val_loss: 1.2896 - val_accuracy: 0.5604
# Epoch 44/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7679 - accuracy: 0.7138 - val_loss: 1.2884 - val_accuracy: 0.5687
# Epoch 45/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7442 - accuracy: 0.7263 - val_loss: 1.2699 - val_accuracy: 0.5657
# Epoch 46/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7424 - accuracy: 0.7234 - val_loss: 1.3113 - val_accuracy: 0.5649
# Epoch 47/100
# 168/168 [==============================] - 4s 24ms/step - loss: 0.7521 - accuracy: 0.7178 - val_loss: 1.2697 - val_accuracy: 0.5567
# Epoch 48/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7247 - accuracy: 0.7338 - val_loss: 1.2462 - val_accuracy: 0.5701
# Epoch 49/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7033 - accuracy: 0.7276 - val_loss: 1.3188 - val_accuracy: 0.5642
# Epoch 50/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.7428 - accuracy: 0.7340 - val_loss: 1.2962 - val_accuracy: 0.5701
# Epoch 51/100
# 168/168 [==============================] - 4s 22ms/step - loss: 0.6601 - accuracy: 0.7534 - val_loss: 1.3300 - val_accuracy: 0.5679
# Epoch 52/100
# 168/168 [==============================] - 3s 20ms/step - loss: 0.6426 - accuracy: 0.7620 - val_loss: 1.3539 - val_accuracy: 0.5657
# Epoch 53/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0
100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.4106 - accuracy: 0.8494 - val_loss: 1.6635 - val_accuracy: 0.5799
# Epoch 79/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.4401 - accuracy: 0.8363 - val_loss: 1.8400 - val_accuracy: 0.5522
# Epoch 80/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.4056 - accuracy: 0.8464 - val_loss: 1.7721 - val_accuracy: 0.5604
# Epoch 81/100
# 168/168 [==============================] - 4s 21ms/step - loss: 0.4454 - accuracy: 0.8410 - val_loss: 1.8905 - val_accuracy: 0.5313
# Epoch 82/100
# 168/168 [==============================] - 3s 19ms/step - loss: 0.3869 - accuracy: 0.8594 - val_loss: 1.7961 - val_accuracy: 0.5545
# Epoch 83/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.3949 - accuracy: 0.8540 - val_loss: 1.7840 - val_accuracy: 0.5649
# Epoch 84/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.3617 - accuracy: 0.8669 - val_loss: 1.8269 - val_accuracy: 0.5552
# Epoch 85/100
# 168/168 [==============================] - 4s 22ms/step - loss: 0.3448 - accuracy: 0.8768 - val_loss: 1.7930 - val_accuracy: 0.5545
# Epoch 86/100
# 168/168 [==============================] - 4s 21ms/step - loss: 0.3468 - accuracy: 0.8704 - val_loss: 1.9775 - val_accuracy: 0.5590
# Epoch 87/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.3814 - accuracy: 0.8637 - val_loss: 1.8950 - val_accuracy: 0.5784
# Epoch 88/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3602 - accuracy: 0.8667 - val_loss: 1.8193 - val_accuracy: 0.5545
# Epoch 89/100
# 168/168 [==============================] - 3s 18ms/step - loss: 0.3704 - accuracy: 0.8667 - val_loss: 1.7998 - val_accuracy: 0.5642
# Epoch 90/100
# 168/168 [==============================] - 4s 23ms/step - loss: 0.3068 - accuracy: 0.8889 - val_loss: 1.9797 - val_accuracy: 0.5560
# Epoch 91/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3189 - accuracy: 0.8876 - val_loss: 1.9989 - val_accuracy: 0.5634
# Epoch 92/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3395 - accuracy: 0.8732 - val_loss: 2.0199 - val_accuracy: 0.5478
# Epoch 93/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3111 - accuracy: 0.8830 - val_loss: 2.0451 - val_accuracy: 0.5724
# Epoch 94/100
# 168/168 [==============================] - 4s 23ms/step - loss: 0.3151 - accuracy: 0.8822 - val_loss: 2.1197 - val_accuracy: 0.5612
# Epoch 95/100
# 168/168 [==============================] - 3s 19ms/step - loss: 0.3212 - accuracy: 0.8846 - val_loss: 2.1573 - val_accuracy: 0.5552
# Epoch 96/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3122 - accuracy: 0.8882 - val_loss: 2.0575 - val_accuracy: 0.5493
# Epoch 97/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.2624 - accuracy: 0.9044 - val_loss: 2.1490 - val_accuracy: 0.5687
# Epoch 98/100
# 168/168 [==============================] - 4s 21ms/step - loss: 0.2892 - accuracy: 0.8981 - val_loss: 2.0717 - val_accuracy: 0.5739
# Epoch 99/100
# 168/168 [==============================] - 3s 20ms/step - loss: 0.2884 - accuracy: 0.8983 - val_loss: 2.1657 - val_accuracy: 0.5597
# Epoch 100/100
# 168/168 [==============================] - 3s 17ms/step - loss: 0.3179 - accuracy: 0.8833 - val_loss: 2.0033 - val_accuracy: 0.5597

# %% [markdown]
# # Evaluation

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print("Test Accuracy: ",test_acc)
# Out:
# Test Accuracy:  0.5704697966575623

# %%
model.save('Speech-Emotion-Recognition-Model.h5')
